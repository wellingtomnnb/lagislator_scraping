# %%
# imports
import bs4
import requests

# %%
def get_soup(url: str):
    """ ### get_soup
    Faz uma requisição GET para a URL passada como parâmetro e
    retorna um objeto do tipo BeautifulSoup
    """

    html_content = requests.get(url).text
    soup = bs4.BeautifulSoup(html_content, 'lxml')
    return soup

# %%
def load_soap_data(soap_data, proposicao:int, ano:int):
    """ ### load_soap_data
    Interpreta os dados oriundos de uma página HTML
    parâmetros:
    * soap_data: objeto do tipo BeautifulSoup com os dados do HTML
    * proposicao: número da proposição
    * ano: ano da proposição (data inicial: 1997)
    """

    # obtém a lista de chave e valores oriundos do body da pagina
    keys = soap_data.find_all('dt')
    values = soap_data.find_all('dd')
    values = soap_data.find_all('dd')

    # cria um dict baseando-se na zipagem das listas
    dados = {
      key.get_text().lower(): value.get_text()
      for key, value in zip(keys, values)
    }

    # obtem o texto do paragrafo
    texto = soap_data.find('p').get_text()

    # cria um novos keys para armazenar os dados extras
    dados['texto'] = texto
    dados['proposicao'] = proposicao
    dados['ano'] = ano

    return dados

# %%
def get_data(ano: int = 2003):
    """### get_data
    Obtém dados a partir do web scraping da pagina *legislador*
    """

    # define mecanismos de manipulação da URL
    url_base = "https://www.legislador.com.br//LegisladorWEB.ASP?WCI=ProposicaoTexto&ID=3&TPProposicao=1&nr"
    url_dynamic =  lambda prop, ano: f'{url_base}Proposicao={prop}&aaProposicao={ano}'
    
    results = [] # inicializa variável que armazenará a lista de proposições
    proposicao_count = 1 # define o contador inicial da proposição

    # faz uma scraping inicial para identificar se houve alguma proposição naquele ano
    raw_data = get_soup( url_dynamic(proposicao_count, ano) )
    has_data = len(raw_data.findAll('dt')) > 0

    # se houver dados para o ano/proposição, continua
    while has_data:
        # adiciona o último resultado a lista de proposições
        results.append(load_soap_data(raw_data, proposicao_count, ano))

        raw_data = get_soup( url_dynamic(proposicao_count, ano) )
        has_data = len(raw_data.findAll('dt')) > 0

        print('proposicao:', f'{ano}-{proposicao_count}', end='\r')
        proposicao_count += 1


    print(f'Total de Preposições em {ano}:', proposicao_count-1)


    return results

# %%
preposicoes = get_data()
len(preposicoes)
# Out:
# Total de Preposições em 2003: 1156
# 1156

# %%
preposicoes[0]
# Out:
# {'reunião': '01/01/2003',
#  'deliberação': '01/01/2003',
#  'situação': 'Proposição Despachada',
#  'assunto': 'Diversos',
#  'autor': 'Bancada SP - Sem Partido',
#  'texto': 'ANEXOS DA LEI DE DIRETRIZES ORÇAMENTÁRIA PARA O EXERCÍCIO DE 2003',
#  'proposicao': 1,
#  'ano': 2003}

# %%
from database import Database
await Database().preposicoes.insert_many(preposicoes)
# Out:
# InsertManyResult([ObjectId('65d2948137c484edc0eb6ac9'), ObjectId('65d2948137c484edc0eb6aca'), ObjectId('65d2948137c484edc0eb6acb'), ObjectId('65d2948137c484edc0eb6acc'), ObjectId('65d2948137c484edc0eb6acd'), ObjectId('65d2948137c484edc0eb6ace'), ObjectId('65d2948137c484edc0eb6acf'), ObjectId('65d2948137c484edc0eb6ad0'), ObjectId('65d2948137c484edc0eb6ad1'), ObjectId('65d2948137c484edc0eb6ad2'), ObjectId('65d2948137c484edc0eb6ad3'), ObjectId('65d2948137c484edc0eb6ad4'), ObjectId('65d2948137c484edc0eb6ad5'), ObjectId('65d2948137c484edc0eb6ad6'), ObjectId('65d2948137c484edc0eb6ad7'), ObjectId('65d2948137c484edc0eb6ad8'), ObjectId('65d2948137c484edc0eb6ad9'), ObjectId('65d2948137c484edc0eb6ada'), ObjectId('65d2948137c484edc0eb6adb'), ObjectId('65d2948137c484edc0eb6adc'), ObjectId('65d2948137c484edc0eb6add'), ObjectId('65d2948137c484edc0eb6ade'), ObjectId('65d2948137c484edc0eb6adf'), ObjectId('65d2948137c484edc0eb6ae0'), ObjectId('65d2948137c484edc0eb6ae1'), ObjectId('65d2948137c484edc0eb6ae2'), ObjectId('65d2948137c484edc0eb6ae3'), ObjectId('65d2948137c484edc0eb6ae4'), ObjectId('65d2948137c484edc0eb6ae5'), ObjectId('65d2948137c484edc0eb6ae6'), ObjectId('65d2948137c484edc0eb6ae7'), ObjectId('65d2948137c484edc0eb6ae8'), ObjectId('65d2948137c484edc0eb6ae9'), ObjectId('65d2948137c484edc0eb6aea'), ObjectId('65d2948137c484edc0eb6aeb'), ObjectId('65d2948137c484edc0eb6aec'), ObjectId('65d2948137c484edc0eb6aed'), ObjectId('65d2948137c484edc0eb6aee'), ObjectId('65d2948137c484edc0eb6aef'), ObjectId('65d2948137c484edc0eb6af0'), ObjectId('65d2948137c484edc0eb6af1'), ObjectId('65d2948137c484edc0eb6af2'), ObjectId('65d2948137c484edc0eb6af3'), ObjectId('65d2948137c484edc0eb6af4'), ObjectId('65d2948137c484edc0eb6af5'), ObjectId('65d2948137c484edc0eb6af6'), ObjectId('65d2948137c484edc0eb6af7'), ObjectId('65d2948137c484edc0eb6af8'), ObjectId('65d2948137c484edc0eb6af9'), ObjectId('65d2948137c484edc0eb6afa'), ObjectId('65d2948137c484edc0eb6afb'), ObjectId('65d2948137c484edc0eb6afc'), ObjectId('65d2948137c484edc0eb6afd'), ObjectId('65d2948137c484edc0eb6afe'), ObjectId('65d2948137c484edc0eb6aff'), ObjectId('65d2948137c484edc0eb6b00'), ObjectId('65d2948137c484edc0eb6b01'), ObjectId('65d2948137c484edc0eb6b02'), ObjectId('65d2948137c484edc0eb6b03'), ObjectId('65d2948137c484edc0eb6b04'), ObjectId('65d2948137c484edc0eb6b05'), ObjectId('65d2948137c484edc0eb6b06'), ObjectId('65d2948137c484edc0eb6b07'), ObjectId('65d2948137c484edc0eb6b08'), ObjectId('65d2948137c484edc0eb6b09'), ObjectId('65d2948137c484edc0eb6b0a'), ObjectId('65d2948137c484edc0eb6b0b'), ObjectId('65d2948137c484edc0eb6b0c'), ObjectId('65d2948137c484edc0eb6b0d'), ObjectId('65d2948137c484edc0eb6b0e'), ObjectId('65d2948137c484edc0eb6b0f'), ObjectId('65d2948137c484edc0eb6b10'), ObjectId('65d2948137c484edc0eb6b11'), ObjectId('65d2948137c484edc0eb6b12'), ObjectId('65d2948137c484edc0eb6b13'), ObjectId('65d2948137c484edc0eb6b14'), ObjectId('65d2948137c484edc0eb6b15'), ObjectId('65d2948137c484edc0eb6b16'), ObjectId('65d2948137c484edc0eb6b17'), ObjectId('65d2948137c484edc0eb6b18'), ObjectId('65d2948137c484edc0eb6b19'), ObjectId('65d2948137c484edc0eb6b1a'), ObjectId('65d2948137c484edc0eb6b1b'), ObjectId('65d2948137c484edc0eb6b1c'), ObjectId('65d2948137c484edc0eb6b1d'), ObjectId('65d2948137c484edc0eb6b1e'), ObjectId('65d2948137c484edc0eb6b1f'), ObjectId('65d2948137c484edc0eb6b20'), ObjectId('65d2948137c484edc0eb6b21'), ObjectId('65d2948137c484edc0eb6b22'), ObjectId('65d2948137c484edc0eb6b23'), ObjectId('65d2948137c484edc0eb6b24'), ObjectId('65d2948137c484edc0eb6b25'), ObjectId('65d2948137c484edc0eb6b26'), ObjectId('65d2948137c484edc0eb6b27'), ObjectId('65d2948137c484edc0eb6b28'), ObjectId('65d2948137c484edc0eb6b29'), ObjectId('65d2948137c484edc0eb6b2a'), ObjectId('65d2948137c484edc0eb6b2b'), ObjectId('65d2948137c484edc0eb6b2c'), ObjectId('65d2948137c484edc0eb6b2d'), ObjectId('65d2948137c484edc0eb6b2e'), ObjectId('65d2948137c484edc0eb6b2f'), ObjectId('65d2948137c484edc0eb6b30'), ObjectId('65d2948137c484edc0eb ...
